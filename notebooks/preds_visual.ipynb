# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.colors import Normalize
import matplotlib.patches as mpatches
from matplotlib.colors import Normalize
import umap
from rdkit import Chem
from rdkit.Chem import rdFingerprintGenerator
# Out:
# 2026-03-18 19:47:03.950221: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
csv_path = "../data/link_invent_outputs/scored_sampling_test_raw_prior_full.csv"
df = pd.read_csv(csv_path)

smi_col = 'SMILES'  
df = df.dropna(subset=[smi_col, 'Active_Probability']).reset_index(drop=True)

mfpgen = rdFingerprintGenerator.GetMorganGenerator(radius=3, fpSize=2048)
fps = []
valid_indices = []

for i, s in enumerate(df[smi_col]):
    if pd.notna(s):
        m = Chem.MolFromSmiles(s)
        if m:
            fps.append(mfpgen.GetFingerprintAsNumPy(m))
            valid_indices.append(i)

fps_array = np.array(fps)
df_valid = df.iloc[valid_indices].copy()

reducer = umap.UMAP(n_neighbors=5, min_dist=0.4, metric='jaccard', random_state=42)
embedding = reducer.fit_transform(fps_array)
# Out:
# /home/va.melnyk@ad.loc/anaconda3/envs/protacs/lib/python3.13/site-packages/umap/umap_.py:1887: UserWarning: gradient function is not yet implemented for jaccard distance metric; inverse_transform will be unavailable
#   warn(
# /home/va.melnyk@ad.loc/anaconda3/envs/protacs/lib/python3.13/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 22
#      19 df_valid = df.iloc[valid_indices].copy()
#      21 reducer = umap.UMAP(n_neighbors=5, min_dist=0.4, metric='jaccard', random_state=42)
# ---> 22 embedding = reducer.fit_transform(fps_array)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/umap/umap_.py:2935, in UMAP.fit_transform(self, X, y, ensure_all_finite, **kwargs)
#    2897 def fit_transform(self, X, y=None, ensure_all_finite=True, **kwargs):
#    2898     """Fit X into an embedded space and return that transformed
#    2899     output.
#    2900
#    (...)   2933         Local radii of data points in the embedding (log-transformed).
#    2934     """
# -> 2935     self.fit(X, y, ensure_all_finite, **kwargs)
#    2936     if self.transform_mode == "embedding":
#    2937         if self.output_dens:
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/umap/umap_.py:2593, in UMAP.fit(self, X, y, ensure_all_finite, **kwargs)
#    2586 edges_removed = np.sum(dmat >= self._disconnection_distance)
#    2587 dmat[dmat >= self._disconnection_distance] = np.inf
#    2588 (
#    2589     self.graph_,
#    2590     self._sigmas,
#    2591     self._rhos,
#    2592     self.graph_dists_,
# -> 2593 ) = fuzzy_simplicial_set(
#    2594     dmat,
#    2595     self._n_neighbors,
#    2596     random_state,
#    2597     "precomputed",
#    2598     self._metric_kwds,
#    2599     None,
#    2600     None,
#    2601     self.angular_rp_forest,
#    2602     self.set_op_mix_ratio,
#    2603     self.local_connectivity,
#    2604     True,
#    2605     self.verbose,
#    2606     self.densmap or self.output_dens,
#    2607 )
#    2608 # Report the number of vertices with degree 0 in our umap.graph_
#    2609 # This ensures that they were properly disconnected.
#    2610 vertices_disconnected = np.sum(
#    2611     np.array(self.graph_.sum(axis=1)).flatten() == 0
#    2612 )
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/umap/umap_.py:578, in fuzzy_simplicial_set(X, n_neighbors, random_state, metric, metric_kwds, knn_indices, knn_dists, angular, set_op_mix_ratio, local_connectivity, apply_set_operations, verbose, return_dists)
#     566     knn_indices, knn_dists, _ = nearest_neighbors(
#     567         X,
#     568         n_neighbors,
#    (...)    573         verbose=verbose,
#     574     )
#     576 knn_dists = knn_dists.astype(np.float32)
# --> 578 sigmas, rhos = smooth_knn_dist(
#     579     knn_dists,
#     580     float(n_neighbors),
#     581     local_connectivity=float(local_connectivity),
#     582 )
#     584 rows, cols, vals, dists = compute_membership_strengths(
#     585     knn_indices, knn_dists, sigmas, rhos, return_dists
#     586 )
#     588 result = scipy.sparse.coo_matrix(
#     589     (vals, (rows, cols)), shape=(X.shape[0], X.shape[0])
#     590 )
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:376, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     374 return_val = None
#     375 try:
# --> 376     return_val = self.compile(tuple(argtypes))
#     377 except errors.ForceLiteralArg as e:
#     378     # Received request for compiler re-entry with the list of arguments
#     379     # indicated by e.requested_args.
#     380     # First, check if any of these args are already Literal-ized
#     381     already_lit_pos = [i for i in e.requested_args
#     382                        if isinstance(args[i], types.Literal)]
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:908, in Dispatcher.compile(self, sig)
#     906 with ev.trigger_event("numba:compile", data=ev_details):
#     907     try:
# --> 908         cres = self._compiler.compile(args, return_type)
#     909     except errors.ForceLiteralArg as e:
#     910         def folded(args, kws):
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)    735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typed_passes.py:114, in BaseTypeInference.run_pass(self, state)
#     108 """
#     109 Type inference and legalization
#     110 """
#     111 with fallback_context(state, 'Function "%s" failed type inference'
#     112                       % (state.func_id.func_name,)):
#     113     # Type inference
# --> 114     typemap, return_type, calltypes, errs = type_inference_stage(
#     115         state.typingctx,
#     116         state.targetctx,
#     117         state.func_ir,
#     118         state.args,
#     119         state.return_type,
#     120         state.locals,
#     121         raise_errors=self._raise_errors)
#     122     state.typemap = typemap
#     123     # save errors in case of partial typing
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typed_passes.py:95, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      93     infer.build_constraint()
#      94     # return errors in case of partial typing
# ---> 95     errs = infer.propagate(raise_errors=raise_errors)
#      96     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      98 return _TypingResults(typemap, restype, calltypes, errs)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typeinfer.py:1075, in TypeInferer.propagate(self, raise_errors)
#    1072 oldtoken = newtoken
#    1073 # Errors can appear when the type set is incomplete; only
#    1074 # raise them when there is no progress anymore.
# -> 1075 errors = self.constraints.propagate(self)
#    1076 newtoken = self.get_state_token()
#    1077 self.debug.propagate_finished()
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typeinfer.py:572, in CallConstraint.__call__(self, typeinfer)
#     569     fnty = typevars[self.func].getone()
#     570 with new_error_context("resolving callee type: {fnty}",
#     571                        fnty=fnty):
# --> 572     self.resolve(typeinfer, typevars, fnty)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typeinfer.py:595, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     593     fnty = fnty.instance_type
#     594 try:
# --> 595     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     596 except ForceLiteralArg as e:
#     597     # Adjust for bound methods
#     598     folding_args = ((fnty.this,) + tuple(self.args)
#     599                     if isinstance(fnty, types.BoundFunction)
#     600                     else self.args)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typeinfer.py:1569, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1566     return sig
#    1567 else:
#    1568     # Normal non-recursive call
# -> 1569     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typing/context.py:279, in BaseContext.resolve_function_type(self, func, args, kws)
#     277 # Prefer user definition first
#     278 try:
# --> 279     res = self._resolve_user_function_type(func, args, kws)
#     280 except errors.TypingError as e:
#     281     # Capture any typing error
#     282     last_exception = e
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typing/context.py:335, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     331         return self.resolve_function_type(func_type, args, kws)
#     333 if isinstance(func, types.Callable):
#     334     # XXX fold this into the __call__ attribute logic?
# --> 335     return func.get_call_type(self, args, kws)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/types/functions.py:311, in BaseFunction.get_call_type(self, context, args, kws)
#     308         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     309         nolitkws = {k: _unlit_non_poison(v)
#     310                     for k, v in kws.items()}
# --> 311         sig = temp.apply(nolitargs, nolitkws)
#     312 except Exception as e:
#     313     if not isinstance(e, errors.NumbaError):
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typing/templates.py:358, in AbstractTemplate.apply(self, args, kws)
#     356 def apply(self, args, kws):
#     357     generic = getattr(self, "generic")
# --> 358     sig = generic(args, kws)
#     359     # Enforce that *generic()* must return None or Signature
#     360     if sig is not None:
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typing/templates.py:621, in _OverloadFunctionTemplate.generic(self, args, kws)
#     615 """
#     616 Type the overloaded function by compiling the appropriate
#     617 implementation for the given args.
#     618 """
#     619 from numba.core.typed_passes import PreLowerStripPhis
# --> 621 disp, new_args = self._get_impl(args, kws)
#     622 if disp is None:
#     623     return
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typing/templates.py:720, in _OverloadFunctionTemplate._get_impl(self, args, kws)
#     716 except KeyError:
#     717     # pass and try outside the scope so as to not have KeyError with a
#     718     # nested addition error in the case the _build_impl fails
#     719     pass
# --> 720 impl, args = self._build_impl(cache_key, args, kws)
#     721 return impl, args
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typing/templates.py:824, in _OverloadFunctionTemplate._build_impl(self, cache_key, args, kws)
#     822 # Make sure that the implementation can be fully compiled
#     823 disp_type = types.Dispatcher(disp)
# --> 824 disp_type.get_call_type(self.context, args, kws)
#     825 if cache_key is not None:
#     826     self._impl_cache[cache_key] = disp, args
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/types/functions.py:541, in Dispatcher.get_call_type(self, context, args, kws)
#     534 def get_call_type(self, context, args, kws):
#     535     """
#     536     Resolve a call to this dispatcher using the given argument types.
#     537     A signature returned and it is ensured that a compiled specialization
#     538     is available for it.
#     539     """
#     540     template, pysig, args, kws = \
# --> 541         self.dispatcher.get_call_template(args, kws)
#     542     sig = template(context).apply(args, kws)
#     543     if sig:
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:319, in _DispatcherBase.get_call_template(self, args, kws)
#     317 # Ensure an overload is available
#     318 if self._can_compile:
# --> 319     self.compile(tuple(args))
#     321 # Create function type for typing
#     322 func_name = self.py_func.__name__
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:908, in Dispatcher.compile(self, sig)
#     906 with ev.trigger_event("numba:compile", data=ev_details):
#     907     try:
# --> 908         cres = self._compiler.compile(args, return_type)
#     909     except errors.ForceLiteralArg as e:
#     910         def folded(args, kws):
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)    735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typed_passes.py:472, in BaseNativeLowering.run_pass(self, state)
#     469 with targetctx.push_code_library(library):
#     470     lower = self.lowering_class(targetctx, library, fndesc, interp,
#     471                                 metadata=metadata)
# --> 472     lower.lower()
#     473     if not flags.no_cpython_wrapper:
#     474         lower.create_cpython_wrapper(flags.release_gil)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/lowering.py:193, in BaseLower.lower(self)
#     191 if self.generator_info is None:
#     192     self.genlower = None
# --> 193     self.lower_normal_function(self.fndesc)
#     194 else:
#     195     self.genlower = self.GeneratorLower(self)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/lowering.py:232, in BaseLower.lower_normal_function(self, fndesc)
#     230 # Init argument values
#     231 self.extract_function_arguments()
# --> 232 entry_block_tail = self.lower_function_body()
#     234 # Close tail of entry block, do not emit debug metadata else the
#     235 # unconditional jump gets associated with the metadata from the function
#     236 # body end.
#     237 with debuginfo.suspend_emission(self.builder):
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/lowering.py:262, in BaseLower.lower_function_body(self)
#     260     self.builder.position_at_end(bb)
#     261     self.debug_print(f"# lower block: {offset}")
# --> 262     self.lower_block(block)
#     263 self.post_lower()
#     264 return entry_block_tail
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/lowering.py:276, in BaseLower.lower_block(self, block)
#     273     defaulterrcls = partial(LoweringError, loc=self.loc)
#     274     with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     275                            loc=self.loc, errcls_=defaulterrcls):
# --> 276         self.lower_inst(inst)
#     277 self.post_block(block)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/lowering.py:462, in Lower.lower_inst(self, inst)
#     460 if isinstance(inst, ir.Assign):
#     461     ty = self.typeof(inst.target.name)
# --> 462     val = self.lower_assign(ty, inst)
#     463     argidx = None
#     464     # If this is a store from an arg, like x = arg.x then tell debuginfo
#     465     # that this is the arg
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/lowering.py:674, in Lower.lower_assign(self, ty, inst)
#     671     return res
#     673 elif isinstance(value, ir.Expr):
# --> 674     return self.lower_expr(ty, value)
#     676 elif isinstance(value, ir.Var):
#     677     val = self.loadvar(value.name)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/lowering.py:1268, in Lower.lower_expr(self, resty, expr)
#    1265     return res
#    1267 elif expr.op == 'call':
# -> 1268     res = self.lower_call(resty, expr)
#    1269     return res
#    1271 elif expr.op == 'pair_first':
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/lowering.py:939, in Lower.lower_call(self, resty, expr)
#     936     res = self._lower_call_FunctionType(fnty, expr, signature)
#     938 else:
# --> 939     res = self._lower_call_normal(fnty, expr, signature)
#     941 # If lowering the call returned None, interpret that as returning dummy
#     942 # value if the return type of the function is void, otherwise there is
#     943 # a problem
#     944 if res is None:
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/lowering.py:1239, in Lower._lower_call_normal(self, fnty, expr, signature)
#    1236     # Prepend the self reference
#    1237     argvals = [the_self] + list(argvals)
# -> 1239 res = impl(self.builder, argvals, self.loc)
#    1240 return res
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/base.py:1196, in _wrap_impl.__call__(self, builder, args, loc)
#    1195 def __call__(self, builder, args, loc=None):
# -> 1196     res = self._imp(self._context, builder, self._sig, args, loc=loc)
#    1197     self._context.add_linking_libs(getattr(self, 'libs', ()))
#    1198     return res
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/base.py:1226, in _wrap_missing_loc.__call__.<locals>.wrapper(*args, **kwargs)
#    1224 def wrapper(*args, **kwargs):
#    1225     kwargs.pop('loc')     # drop unused loc
# -> 1226     return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typing/templates.py:1113, in _OverloadMethodTemplate._init_once.<locals>.method_impl(context, builder, sig, args)
#    1111 typing_context = context.typing_context
#    1112 fnty = self._get_function_type(typing_context, typ)
# -> 1113 sig = self._get_signature(typing_context, fnty, sig.args, {})
#    1114 call = context.get_function(fnty, sig)
#    1115 # Link dependent library
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typing/templates.py:1085, in _OverloadAttributeTemplate._get_signature(cls, typingctx, fnty, args, kws)
#    1083 @classmethod
#    1084 def _get_signature(cls, typingctx, fnty, args, kws):
# -> 1085     sig = fnty.get_call_type(typingctx, args, kws)
#    1086     sig = sig.replace(pysig=utils.pysignature(cls._overload_func))
#    1087     return sig
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/types/functions.py:311, in BaseFunction.get_call_type(self, context, args, kws)
#     308         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     309         nolitkws = {k: _unlit_non_poison(v)
#     310                     for k, v in kws.items()}
# --> 311         sig = temp.apply(nolitargs, nolitkws)
#     312 except Exception as e:
#     313     if not isinstance(e, errors.NumbaError):
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typing/templates.py:358, in AbstractTemplate.apply(self, args, kws)
#     356 def apply(self, args, kws):
#     357     generic = getattr(self, "generic")
# --> 358     sig = generic(args, kws)
#     359     # Enforce that *generic()* must return None or Signature
#     360     if sig is not None:
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typing/templates.py:621, in _OverloadFunctionTemplate.generic(self, args, kws)
#     615 """
#     616 Type the overloaded function by compiling the appropriate
#     617 implementation for the given args.
#     618 """
#     619 from numba.core.typed_passes import PreLowerStripPhis
# --> 621 disp, new_args = self._get_impl(args, kws)
#     622 if disp is None:
#     623     return
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typing/templates.py:720, in _OverloadFunctionTemplate._get_impl(self, args, kws)
#     716 except KeyError:
#     717     # pass and try outside the scope so as to not have KeyError with a
#     718     # nested addition error in the case the _build_impl fails
#     719     pass
# --> 720 impl, args = self._build_impl(cache_key, args, kws)
#     721 return impl, args
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/typing/templates.py:824, in _OverloadFunctionTemplate._build_impl(self, cache_key, args, kws)
#     822 # Make sure that the implementation can be fully compiled
#     823 disp_type = types.Dispatcher(disp)
# --> 824 disp_type.get_call_type(self.context, args, kws)
#     825 if cache_key is not None:
#     826     self._impl_cache[cache_key] = disp, args
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/types/functions.py:541, in Dispatcher.get_call_type(self, context, args, kws)
#     534 def get_call_type(self, context, args, kws):
#     535     """
#     536     Resolve a call to this dispatcher using the given argument types.
#     537     A signature returned and it is ensured that a compiled specialization
#     538     is available for it.
#     539     """
#     540     template, pysig, args, kws = \
# --> 541         self.dispatcher.get_call_template(args, kws)
#     542     sig = template(context).apply(args, kws)
#     543     if sig:
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:319, in _DispatcherBase.get_call_template(self, args, kws)
#     317 # Ensure an overload is available
#     318 if self._can_compile:
# --> 319     self.compile(tuple(args))
#     321 # Create function type for typing
#     322 func_name = self.py_func.__name__
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:908, in Dispatcher.compile(self, sig)
#     906 with ev.trigger_event("numba:compile", data=ev_details):
#     907     try:
# --> 908         cres = self._compiler.compile(args, return_type)
#     909     except errors.ForceLiteralArg as e:
#     910         def folded(args, kws):
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler.py:737, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     713 def compile_extra(typingctx, targetctx, func, args, return_type, flags,
#     714                   locals, library=None, pipeline_class=Compiler):
#     715     """Compiler entry point
#     716
#     717     Parameter
#    (...)    735         compiler pipeline
#     736     """
# --> 737     pipeline = pipeline_class(typingctx, targetctx, library,
#     738                               args, return_type, flags, locals)
#     739     return pipeline.compile_extra(func)
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/compiler.py:394, in CompilerBase.__init__(self, typingctx, targetctx, library, args, return_type, flags, locals)
#     391 def __init__(self, typingctx, targetctx, library, args, return_type, flags,
#     392              locals):
#     393     # Make sure the environment is reloaded
# --> 394     config.reload_config()
#     395     typingctx.refresh()
#     396     targetctx.refresh()
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/config.py:602, in reload_config()
#     598 def reload_config():
#     599     """
#     600     Reload the configuration from environment variables, if necessary.
#     601     """
# --> 602     _env_reloader.update()
#
# File ~/anaconda3/envs/protacs/lib/python3.13/site-packages/numba/core/config.py:144, in _EnvReloader.update(self, force)
#     141                 new_environ['NUMBA_' + k.upper()] = v
#     143 # clobber file based config with any locally defined env vars
# --> 144 for name, value in os.environ.items():
#     145     if name.startswith('NUMBA_'):
#     146         new_environ[name] = value
#
# File <frozen _collections_abc>:827, in items(self)
#
# KeyboardInterrupt:

# %%
prob_mean = df_valid['Active_Probability'].mean()
print(prob_mean)
# Out:
# 0.5902614374774128

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman', 'DejaVu Serif']
plt.rcParams['axes.unicode_minus'] = False

# --- DYNAMIC COLOR MAPPING ---
# Calculate the exact boundaries of your actual predictions
prob_min = df_valid['Active_Probability'].min()
prob_max = df_valid['Active_Probability'].max()

# The colormap will now stretch perfectly from prob_min to prob_max
norm = Normalize(vmin=prob_min, vmax=prob_max)
cmap = plt.get_cmap('RdBu_r')

# --- 1x3 Layout ---
fig = plt.figure(figsize=(18, 7))
gs = gridspec.GridSpec(1, 3, width_ratios=[4, 4, 2], wspace=0.05)

ax_umap_class = plt.subplot(gs[0])
ax_umap_prob = plt.subplot(gs[1])
ax_hist = plt.subplot(gs[2]) 

# --- UMAP Plot 1: Binary Class ---
# Extract exact colors from the RdBu_r colormap extremes for the binary plot
color_inactive = cmap(0.05) # Deep Red
color_active = cmap(0.95)   # Deep Blue
class_colors = [color_active if val == 1 else color_inactive for val in df_valid['Active_Class']]

ax_umap_class.scatter(
    embedding[:, 0], embedding[:, 1], 
    c=class_colors, 
    s=85, 
    alpha=0.85, 
    edgecolor='black', 
    linewidth=0.5,
    zorder=3
)

ax_umap_class.set_title('Бінарна класифікація', fontsize=15, fontweight='bold', pad=10)
ax_umap_class.set_xlabel('UMAP Вимір 1', fontsize=14)
ax_umap_class.set_ylabel('UMAP Вимір 2', fontsize=14)
ax_umap_class.grid(True, linestyle='-', alpha=0.5, zorder=1)

# Calculate counts for each class
num_active = (df_valid['Active_Class'] == 1).sum()
num_inactive = (df_valid['Active_Class'] == 0).sum()

# Custom legend for binary class with counts
legend_elements = [
    mpatches.Circle((0, 0), radius=5, facecolor=color_inactive, edgecolor='black', label=f'Неактивні (n={num_inactive})'),
    mpatches.Circle((0, 0), radius=5, facecolor=color_active, edgecolor='black', label=f'Активні (n={num_active})')
]
ax_umap_class.legend(handles=legend_elements, loc='best', fontsize=12)

# --- UMAP Plot 2: Continuous Probability ---
scatter_prob = ax_umap_prob.scatter(
    embedding[:, 0], embedding[:, 1], 
    c=df_valid['Active_Probability'], 
    cmap=cmap, 
    norm=norm,
    s=85, 
    alpha=0.85, 
    edgecolor='black', 
    linewidth=0.5,
    zorder=3
)

ax_umap_prob.set_title('Ймовірність активності', fontsize=15, fontweight='bold', pad=10)
ax_umap_prob.set_xlabel('UMAP Вимір 1', fontsize=14)
ax_umap_prob.grid(True, linestyle='-', alpha=0.5, zorder=1)
# Remove y-ticks for the middle plot to keep it clean
ax_umap_prob.set_yticklabels([])
#ax_umap_prob.set_yticks([])

fig.suptitle(f'Структурний ландшафт та розподіл активності апріорної вибірки PROTAC (n={len(df_valid)})', 
             fontsize=18, 
             fontweight='bold', 
             y=0.98)

# --- Vertical Gradient Histogram (The "Dynamic Colorbar") ---
n_bins = 30
counts, bins, patches = ax_hist.hist(
    df_valid['Active_Probability'], 
    bins=n_bins, 
    range=(prob_min, prob_max), # Lock histogram to the actual data range
    orientation='horizontal', 
    edgecolor='black', 
    linewidth=0.5
)

# Color each bar based on the exact center of its probability bin
for bin_left, bin_right, patch in zip(bins[:-1], bins[1:], patches):
    bin_center = (bin_left + bin_right) / 2
    color = cmap(norm(bin_center))
    patch.set_facecolor(color)

ax_hist.set_xlabel('Кількість сполук', fontsize=14)
ax_hist.set_ylabel('Ймовірність активності', fontsize=14, rotation=270, labelpad=20)
ax_hist.grid(True, axis='y', linestyle='-', alpha=0.4)
ax_hist.grid(True, axis='x', linestyle='-', alpha=0.4)
ax_hist.yaxis.set_label_position("right")
ax_hist.yaxis.tick_right()
ax_hist.tick_params(axis='y', which='both', length=0)

# Add a horizontal dashed line showing your optimal threshold
optimal_threshold = 0.8
ax_hist.axhline(optimal_threshold, color='black', linestyle='--', linewidth=1.5, zorder=5)
ax_hist.text(max(counts)*0.25, optimal_threshold - 0.02, 'Поріг класифікації', fontsize=10, color='black')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
# Out:
# /tmp/ipykernel_516473/591402257.py:109: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman', 'DejaVu Serif']
plt.rcParams['axes.unicode_minus'] = False

# --- DYNAMIC COLOR MAPPING ---
# Calculate the exact boundaries of your actual predictions
prob_min = df_valid['Active_Probability'].min()
prob_max = df_valid['Active_Probability'].max()

# The colormap will now stretch perfectly from prob_min to prob_max
norm = Normalize(vmin=prob_min, vmax=prob_max)
cmap = plt.get_cmap('RdBu_r')

# --- 1x3 Layout ---
fig = plt.figure(figsize=(18, 7))
gs = gridspec.GridSpec(1, 3, width_ratios=[4, 4, 2], wspace=0.05)

ax_umap_class = plt.subplot(gs[0])
ax_umap_prob = plt.subplot(gs[1])
ax_hist = plt.subplot(gs[2]) 

# --- UMAP Plot 1: Binary Class ---
# Extract exact colors from the RdBu_r colormap extremes for the binary plot
color_inactive = cmap(0.10) # Deep Red
color_active = cmap(0.90)   # Deep Blue
class_colors = [color_active if val == 1 else color_inactive for val in df_valid['Active_Class']]

ax_umap_class.scatter(
    embedding[:, 0], embedding[:, 1], 
    c=class_colors, 
    s=85, 
    alpha=0.85, 
    edgecolor='black', 
    linewidth=0.5,
    zorder=3
)

ax_umap_class.set_title('Binary Classification', fontsize=18, fontweight='bold', pad=10)
ax_umap_class.set_xlabel('UMAP Dimension 1', fontsize=16)
ax_umap_class.set_ylabel('UMAP Dimension 2', fontsize=16)
ax_umap_class.grid(True, linestyle='-', alpha=0.5, zorder=1)

# Calculate counts for each class
num_active = (df_valid['Active_Class'] == 1).sum()
num_inactive = (df_valid['Active_Class'] == 0).sum()

# Custom legend for binary class with counts
legend_elements = [
    mpatches.Circle((0, 0), radius=5, facecolor=color_inactive, edgecolor='black', label=f'Inactive (n={num_inactive})'),
    mpatches.Circle((0, 0), radius=5, facecolor=color_active, edgecolor='black', label=f'Active (n={num_active})')
]
ax_umap_class.legend(handles=legend_elements, loc='best', fontsize=14)
ax_umap_class.tick_params(axis='both', labelsize=14)

# --- UMAP Plot 2: Continuous Probability ---
scatter_prob = ax_umap_prob.scatter(
    embedding[:, 0], embedding[:, 1], 
    c=df_valid['Active_Probability'], 
    cmap=cmap, 
    norm=norm,
    s=85, 
    alpha=0.85, 
    edgecolor='black', 
    linewidth=0.5,
    zorder=3
)

ax_umap_prob.set_title('Activity Probability', fontsize=18, fontweight='bold', pad=10)
ax_umap_prob.set_xlabel('UMAP Dimension 1', fontsize=16)
ax_umap_prob.grid(True, linestyle='-', alpha=0.5, zorder=1)
# Remove y-ticks for the middle plot to keep it clean
ax_umap_prob.set_yticklabels([])
#ax_umap_prob.set_yticks([])
ax_umap_prob.tick_params(axis='both', labelsize=14)

fig.suptitle(f'Structural Landscape and Activity Distribution of the PROTAC Prior Dataset (n={len(df_valid)})', 
             fontsize=20, 
             fontweight='bold', 
             y=0.98)

# --- Vertical Gradient Histogram (The "Dynamic Colorbar") ---
n_bins = 30
counts, bins, patches = ax_hist.hist(
    df_valid['Active_Probability'], 
    bins=n_bins, 
    range=(prob_min, prob_max), # Lock histogram to the actual data range
    orientation='horizontal', 
    edgecolor='black', 
    linewidth=0.5
)

# Color each bar based on the exact center of its probability bin
for bin_left, bin_right, patch in zip(bins[:-1], bins[1:], patches):
    bin_center = (bin_left + bin_right) / 2
    color = cmap(norm(bin_center))
    patch.set_facecolor(color)

ax_hist.set_xlabel('Number of Compounds', fontsize=16)
ax_hist.set_ylabel('Activity Probability', fontsize=16, rotation=270, labelpad=20)
ax_hist.grid(True, axis='y', linestyle='-', alpha=0.4)
ax_hist.grid(True, axis='x', linestyle='-', alpha=0.4)
ax_hist.yaxis.set_label_position("right")
ax_hist.yaxis.tick_right()
ax_hist.tick_params(axis='y', which='both', length=0)
ax_hist.tick_params(axis='both', labelsize=14)

# Add a horizontal dashed line showing your optimal threshold
optimal_threshold = 0.8
ax_hist.axhline(optimal_threshold, color='black', linestyle='--', linewidth=1.5, zorder=5)
ax_hist.text(max(counts)*0.35, optimal_threshold - 0.02, 'Threshold', fontsize=14, color='black')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig("binary_classification_raw_prior.png", dpi=400, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_516473/3203059719.py:112: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.95])
